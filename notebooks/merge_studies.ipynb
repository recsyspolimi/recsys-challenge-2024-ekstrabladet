# %%
import optuna

storage = "mysql+pymysql://admin:MLZwrgaib8iha7DU9jgP@recsys2024-db.crio26omekmi.eu-west-1.rds.amazonaws.com/recsys2024"
original_study = optuna.load_study(study_name='catboost_ranker_127', storage=storage)
new_study = optuna.load_study(study_name='catboost_ranker_127_s2', storage=storage)

# %%
trial = original_study.trials[-1]
trial.state == optuna.trial.TrialState.COMPLETE
# Out:
# False

# %%
original_study.trials
# Out:
# [FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.7290325906130066], datetime_start=datetime.datetime(2024, 4, 30, 18, 11, 20), datetime_complete=datetime.datetime(2024, 4, 30, 19, 5, 30), params={'iterations': 915, 'learning_rate': 0.11561426957173253, 'rsm': 0.11498140461540353, 'reg_lambda': 1.1189400170411484e-05, 'grow_policy': 'Depthwise', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3968134981040034, 'random_strength': 2.4521935825510743, 'fold_permutation_block': 71, 'border_count': 13, 'sampling_frequency': 'PerTree', 'score_function': 'L2', 'depth': 3, 'min_data_in_leaf': 42.97352457130665}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'iterations': IntDistribution(high=5000, log=False, low=100, step=1), 'learning_rate': FloatDistribution(high=0.2, log=True, low=0.005, step=None), 'rsm': FloatDistribution(high=0.8, log=True, low=0.05, step=None), 'reg_lambda': FloatDistribution(high=1000.0, log=True, low=1e-05, step=None), 'grow_policy':
# ...

# %%
new_study.trials
# Out:
# [FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.7374788067063773], datetime_start=datetime.datetime(2024, 5, 1, 22, 10, 21), datetime_complete=datetime.datetime(2024, 5, 1, 23, 39, 42), params={'iterations': 2380, 'learning_rate': 0.06382163831176961, 'rsm': 0.10815202576324623, 'reg_lambda': 6.053478999833601e-05, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'MVS', 'subsample': 0.3974452605373258, 'random_strength': 0.0004863832758562329, 'fold_permutation_block': 55, 'border_count': 34, 'sampling_frequency': 'PerTree', 'score_function': 'L2', 'depth': 5, 'mvs_reg': 4335.339452540141}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'iterations': IntDistribution(high=5000, log=False, low=100, step=1), 'learning_rate': FloatDistribution(high=0.2, log=True, low=0.005, step=None), 'rsm': FloatDistribution(high=0.8, log=True, low=0.05, step=None), 'reg_lambda': FloatDistribution(high=1000.0, log=True, low=1e-05, step=None), 'grow_policy': Categori
# ...

# %%
completed_trials = [tr for tr in original_study.trials if tr.state == optuna.trial.TrialState.COMPLETE]
completed_trials
# Out:
# [FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.7290325906130066], datetime_start=datetime.datetime(2024, 4, 30, 18, 11, 20), datetime_complete=datetime.datetime(2024, 4, 30, 19, 5, 30), params={'iterations': 915, 'learning_rate': 0.11561426957173253, 'rsm': 0.11498140461540353, 'reg_lambda': 1.1189400170411484e-05, 'grow_policy': 'Depthwise', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3968134981040034, 'random_strength': 2.4521935825510743, 'fold_permutation_block': 71, 'border_count': 13, 'sampling_frequency': 'PerTree', 'score_function': 'L2', 'depth': 3, 'min_data_in_leaf': 42.97352457130665}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'iterations': IntDistribution(high=5000, log=False, low=100, step=1), 'learning_rate': FloatDistribution(high=0.2, log=True, low=0.005, step=None), 'rsm': FloatDistribution(high=0.8, log=True, low=0.05, step=None), 'reg_lambda': FloatDistribution(high=1000.0, log=True, low=1e-05, step=None), 'grow_policy':
# ...

# %%
new_study.add_trials(completed_trials)

# %%
new_study.trials
# Out:
# [FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.7374788067063773], datetime_start=datetime.datetime(2024, 5, 1, 22, 10, 21), datetime_complete=datetime.datetime(2024, 5, 1, 23, 39, 42), params={'iterations': 2380, 'learning_rate': 0.06382163831176961, 'rsm': 0.10815202576324623, 'reg_lambda': 6.053478999833601e-05, 'grow_policy': 'SymmetricTree', 'bootstrap_type': 'MVS', 'subsample': 0.3974452605373258, 'random_strength': 0.0004863832758562329, 'fold_permutation_block': 55, 'border_count': 34, 'sampling_frequency': 'PerTree', 'score_function': 'L2', 'depth': 5, 'mvs_reg': 4335.339452540141}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'iterations': IntDistribution(high=5000, log=False, low=100, step=1), 'learning_rate': FloatDistribution(high=0.2, log=True, low=0.005, step=None), 'rsm': FloatDistribution(high=0.8, log=True, low=0.05, step=None), 'reg_lambda': FloatDistribution(high=1000.0, log=True, low=1e-05, step=None), 'grow_policy': Categori
# ...
